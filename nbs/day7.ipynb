# %% [markdown]
# # Day 7

# %%
import pandas as pd

# %%
with open('/Users/williamkirkland/Data/KDS/adventofcode/2022/data/day7.txt') as file:
    master_list = [line.rstrip() for line in file]

# %%
master_list
# Out:
# ['$ cd /',
#  '$ ls',
#  'dir fpljqj',
#  '171526 ghtzhjwf.nls',
#  'dir gsdsbld',
#  'dir hbmjtb',
#  '296801 mjfjqw.ccv',
#  'dir nfn',
#  'dir qmrsvfvw',
#  '102565 qqjnqb.chd',
#  'dir svgbqd',
#  '$ cd fpljqj',
#  '$ ls',
#  '153563 ghtzhjwf.nls',
#  '243252 gsvjgj.jsm',
#  '154134 hghnrbqg.rzb',
#  '$ cd ..',
#  '$ cd gsdsbld',
#  '$ ls',
#  'dir npmncvhh',
#  'dir qmrsvfvw',
#  'dir sqtnlr',
#  'dir vzndpc',
#  '$ cd npmncvhh',
#  '$ ls',
#  '81366 dwbgr.ztr',
#  '144577 fzjmcq',
#  'dir mphhrqf',
#  'dir rnmvggfd',
#  '276454 zfl.ghv',
#  '$ cd mphhrqf',
#  '$ ls',
#  'dir qlcfs',
#  '111207 shmcrf.wlr',
#  'dir zwsnwvnv',
#  '$ cd qlcfs',
#  '$ ls',
#  '283904 fpljqj.pdw',
#  '83520 hsclcqqt.pff',
#  'dir htwl',
#  'dir lqjhfdch',
#  '5842 mdjzmbc.qtv',
#  'dir nqfdhlcg',
#  '120167 twgqhvft.cgw',
#  '186998 zclhcr',
#  'dir zfl',
#  'dir zlqgr',
#  '$ cd htwl',
#  '$ ls',
#  '268134 hmwnn.htq',
#  '$ cd ..',
#  '$ cd lqjhfdch',
#  '$ ls',
#  '21479 tpdsgf.hgd',
#  '$ cd ..',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  'dir dhjfqv',
#  '203675 ghtzhjwf.nls',
#  '39527 qfwdmzfv.ggd',
#  '$ cd dhjfqv',
#  '$ ls',
#  '135074 dqs.wht',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  '17334 wlsd',
#  '$ cd ..',
#  '$ cd zlqgr',
#  '$ ls',
#  'dir crs',
#  'dir whrm',
#  'dir zfl',
#  '$ cd crs',
#  '$ ls',
#  '220281 szft.bjb',
#  '$ cd ..',
#  '$ cd whrm',
#  '$ ls',
#  '279796 pcnl',
#  'dir pjzpqs',
#  '$ cd pjzpqs',
#  '$ ls',
#  'dir smz',
#  '192921 sqtst.lcz',
#  '21397 trst',
#  '154861 vtgdsnmv',
#  '$ cd smz',
#  '$ ls',
#  '249693 mjfjqw.ccv',
#  'dir tdwqpg',
#  '$ cd tdwqpg',
#  '$ ls',
#  '157907 wjv.rth',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  'dir hwlhshtr',
#  '$ cd hwlhshtr',
#  '$ ls',
#  '90468 srrv.jst',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zwsnwvnv',
#  '$ ls',
#  '209371 ctmcqlz.nwh',
#  '154262 nqngjf',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd rnmvggfd',
#  '$ ls',
#  'dir czzrdvc',
#  '203540 dnwtwzd',
#  'dir fcsjqg',
#  'dir fwdprwpq',
#  '74582 qlnqwnzp.ttz',
#  'dir tvglfb',
#  '$ cd czzrdvc',
#  '$ ls',
#  'dir blplbjpw',
#  '$ cd blplbjpw',
#  '$ ls',
#  '2835 zfl.zvw',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd fcsjqg',
#  '$ ls',
#  '81548 ghtzhjwf.nls',
#  '$ cd ..',
#  '$ cd fwdprwpq',
#  '$ ls',
#  '11156 gsvjgj.jsm',
#  '75010 rgscvjq.zlw',
#  '122327 szft.bjb',
#  'dir zfl',
#  '268883 zpgcwvjf',
#  '$ cd zfl',
#  '$ ls',
#  'dir sphpbjt',
#  '$ cd sphpbjt',
#  '$ ls',
#  '31414 qfwdmzfv.ggd',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd tvglfb',
#  '$ ls',
#  '118050 gsvjgj.jsm',
#  '265116 sdmldsd.hhm',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  'dir fpljqj',
#  '203965 szft.bjb',
#  'dir zcgfg',
#  '$ cd fpljqj',
#  '$ ls',
#  'dir gqvmv',
#  '$ cd gqvmv',
#  '$ ls',
#  '175614 mjfjqw.ccv',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zcgfg',
#  '$ ls',
#  '110104 ddzcbm.qtb',
#  'dir fpglbth',
#  '148639 nqfdhlcg.fsz',
#  'dir pfjz',
#  '166120 wjrmgl',
#  '$ cd fpglbth',
#  '$ ls',
#  '58850 qlggch.tng',
#  '$ cd ..',
#  '$ cd pfjz',
#  '$ ls',
#  '197076 wplpj',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd sqtnlr',
#  '$ ls',
#  '189086 gsvjgj.jsm',
#  'dir ngr',
#  '210016 pmprhlg.rsg',
#  '277979 szft.bjb',
#  '282202 tfqcnn.hlf',
#  '$ cd ngr',
#  '$ ls',
#  'dir fdhd',
#  'dir hwsqqt',
#  'dir qmrsvfvw',
#  '$ cd fdhd',
#  '$ ls',
#  '7384 fhhp',
#  'dir fpljqj',
#  '91732 nqfdhlcg.gwf',
#  '69137 ptcrmc.wwr',
#  '$ cd fpljqj',
#  '$ ls',
#  '282109 rtfhcbc.pqj',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd hwsqqt',
#  '$ ls',
#  '174820 zvmgv.tcd',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '228739 qfwdmzfv.ggd',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd vzndpc',
#  '$ ls',
#  '183360 fpljqj.nbh',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd hbmjtb',
#  '$ ls',
#  '219988 hlvjdg',
#  'dir lndmtm',
#  '107247 rtpvh.srl',
#  'dir sgt',
#  'dir tgjszvsg',
#  '166122 zrshs.phz',
#  'dir ztrvv',
#  '$ cd lndmtm',
#  '$ ls',
#  'dir fpljqj',
#  'dir hscwh',
#  'dir wjv',
#  '$ cd fpljqj',
#  '$ ls',
#  '102717 qmrsvfvw',
#  '$ cd ..',
#  '$ cd hscwh',
#  '$ ls',
#  'dir qgz',
#  'dir qmrsvfvw',
#  '$ cd qgz',
#  '$ ls',
#  '281901 szft.bjb',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '102781 fpljqj.gtv',
#  '197014 gsvjgj.jsm',
#  '174895 pvz',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd wjv',
#  '$ ls',
#  'dir fpljqj',
#  '295195 mjfjqw.ccv',
#  '214886 qfwdmzfv.ggd',
#  'dir qmrsvfvw',
#  '72164 vncjvfhh',
#  '$ cd fpljqj',
#  '$ ls',
#  'dir fpljqj',
#  'dir fzbppql',
#  'dir jpqqr',
#  'dir lzq',
#  'dir pjjbmllm',
#  'dir qmrsvfvw',
#  '$ cd fpljqj',
#  '$ ls',
#  '260943 ghtzhjwf.nls',
#  '$ cd ..',
#  '$ cd fzbppql',
#  '$ ls',
#  '29399 wjv',
#  '$ cd ..',
#  '$ cd jpqqr',
#  '$ ls',
#  '45275 zcwbrvd',
#  '$ cd ..',
#  '$ cd lzq',
#  '$ ls',
#  '180833 szft.bjb',
#  '$ cd ..',
#  '$ cd pjjbmllm',
#  '$ ls',
#  '64063 mjfjqw.ccv',
#  '183683 vrfd.wlw',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '226047 szft.bjb',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  'dir bzcfzh',
#  '272794 lnzpvhj',
#  'dir vsrgqmlt',
#  'dir zbthlb',
#  '$ cd bzcfzh',
#  '$ ls',
#  '63095 mjfjqw.ccv',
#  '45335 nqfdhlcg',
#  '162307 vqqt.vbg',
#  '$ cd ..',
#  '$ cd vsrgqmlt',
#  '$ ls',
#  'dir nqfdhlcg',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  'dir wjv',
#  '$ cd wjv',
#  '$ ls',
#  '81528 cslzgjtp.qzg',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zbthlb',
#  '$ ls',
#  'dir hjp',
#  'dir twfw',
#  'dir zfl',
#  '$ cd hjp',
#  '$ ls',
#  '20745 pvjwrzsl.pmg',
#  '$ cd ..',
#  '$ cd twfw',
#  '$ ls',
#  'dir csmmbjhp',
#  '$ cd csmmbjhp',
#  '$ ls',
#  '165998 nlsd',
#  '109132 vbjlnqt.lsd',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  '227633 jcs.vhj',
#  'dir tvfhvbp',
#  '$ cd tvfhvbp',
#  '$ ls',
#  '116169 lgv',
#  '175862 qfwdmzfv.ggd',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd sgt',
#  '$ ls',
#  '151135 nqfdhlcg',
#  '226449 nqfdhlcg.sqp',
#  '148179 wjv.fgc',
#  '$ cd ..',
#  '$ cd tgjszvsg',
#  '$ ls',
#  '98354 szft.bjb',
#  '$ cd ..',
#  '$ cd ztrvv',
#  '$ ls',
#  '163992 blmmm.gcf',
#  'dir fghl',
#  'dir fpljqj',
#  '226325 nqfdhlcg',
#  'dir qmrsvfvw',
#  '284965 vhbffmcg.fwt',
#  '$ cd fghl',
#  '$ ls',
#  'dir lgpwpmzp',
#  'dir sqjqg',
#  '$ cd lgpwpmzp',
#  '$ ls',
#  'dir ctr',
#  'dir nqfdhlcg',
#  '279439 zfl.npd',
#  '$ cd ctr',
#  '$ ls',
#  '64805 jfflsd.gbc',
#  '163058 zbvpc.znm',
#  '$ cd ..',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  '40180 jsqtwpt.qtq',
#  '87408 rmpbprz.lwr',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd sqjqg',
#  '$ ls',
#  '140444 bsglv',
#  '214121 crzdv.dcc',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd fpljqj',
#  '$ ls',
#  '56575 gqw.dzr',
#  '293957 gsvjgj.jsm',
#  '272507 jvd',
#  'dir tgfvcpp',
#  '178972 vndshbth.mzw',
#  'dir zwtz',
#  '$ cd tgfvcpp',
#  '$ ls',
#  'dir bhq',
#  '$ cd bhq',
#  '$ ls',
#  '111454 gvq',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zwtz',
#  '$ ls',
#  '39290 nqfdhlcg',
#  '140517 qfwdmzfv.ggd',
#  'dir tcnv',
#  '177429 zlzsq.fph',
#  '$ cd tcnv',
#  '$ ls',
#  '286997 fpljqj.phd',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '252862 jbznh',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd nfn',
#  '$ ls',
#  'dir fqw',
#  'dir mpz',
#  'dir qmrsvfvw',
#  'dir zfl',
#  '$ cd fqw',
#  '$ ls',
#  '144372 ghtzhjwf.nls',
#  '100013 mqwwjbvz.scd',
#  '95547 vspwhq.dwn',
#  '$ cd ..',
#  '$ cd mpz',
#  '$ ls',
#  'dir gntjg',
#  'dir jfbhz',
#  '7835 nqfdhlcg',
#  'dir vpgpz',
#  'dir zfl',
#  '$ cd gntjg',
#  '$ ls',
#  'dir hdq',
#  'dir hvcdpzr',
#  'dir lth',
#  '27002 mjfjqw.ccv',
#  'dir qmrsvfvw',
#  'dir scncl',
#  '$ cd hdq',
#  '$ ls',
#  'dir jwhnt',
#  '$ cd jwhnt',
#  '$ ls',
#  '153428 fswqv.jpf',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd hvcdpzr',
#  '$ ls',
#  'dir fpljqj',
#  '135000 fpljqj.smw',
#  '275125 hrqwfjjz.rdj',
#  'dir pmcpnqrr',
#  '58960 qljhbczf.qfn',
#  '222912 szft.bjb',
#  'dir wvvzbt',
#  '$ cd fpljqj',
#  '$ ls',
#  '282896 nqfdhlcg.bjm',
#  '$ cd ..',
#  '$ cd pmcpnqrr',
#  '$ ls',
#  'dir nwjzld',
#  'dir tfdcg',
#  'dir vwlbtgnh',
#  '$ cd nwjzld',
#  '$ ls',
#  '74948 wjv.psf',
#  '$ cd ..',
#  '$ cd tfdcg',
#  '$ ls',
#  '77925 gsvjgj.jsm',
#  'dir lcdfdmlj',
#  'dir pthwnf',
#  '227063 qfwdmzfv.ggd',
#  '293860 qmwr.csp',
#  '154426 scwd.mdc',
#  '$ cd lcdfdmlj',
#  '$ ls',
#  '52503 mjfjqw.ccv',
#  '$ cd ..',
#  '$ cd pthwnf',
#  '$ ls',
#  '176935 fgcwjjz',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd vwlbtgnh',
#  '$ ls',
#  'dir nqfdhlcg',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  'dir lnwtl',
#  '$ cd lnwtl',
#  '$ ls',
#  '252540 cgj.pdg',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd wvvzbt',
#  '$ ls',
#  '25603 bvhd',
#  '24426 qzwgj.bmb',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd lth',
#  '$ ls',
#  'dir dmbf',
#  '60608 ghtzhjwf.nls',
#  'dir ndbcrvw',
#  'dir shsgqzn',
#  '27467 zfl.tdf',
#  '$ cd dmbf',
#  '$ ls',
#  'dir zpggmccr',
#  '$ cd zpggmccr',
#  '$ ls',
#  '238504 hqsgz.jfh',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ndbcrvw',
#  '$ ls',
#  '289441 bwbdc',
#  'dir zfl',
#  '84967 zhwz',
#  '$ cd zfl',
#  '$ ls',
#  '95245 mjfjqw.ccv',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd shsgqzn',
#  '$ ls',
#  '184543 gqrthw.gwf',
#  '61456 wzbbsqrp',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  'dir bql',
#  '247487 szvbjdjl',
#  '58312 wjv',
#  '241150 wjv.ltm',
#  '$ cd bql',
#  '$ ls',
#  '93199 fpljqj',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd scncl',
#  '$ ls',
#  '13092 clgmqlfl',
#  'dir dcldv',
#  'dir fsrznscl',
#  '21910 nqfdhlcg.lld',
#  'dir prcgb',
#  '$ cd dcldv',
#  '$ ls',
#  '271970 nqfdhlcg.dgv',
#  '$ cd ..',
#  '$ cd fsrznscl',
#  '$ ls',
#  'dir bcdrv',
#  '$ cd bcdrv',
#  '$ ls',
#  '96252 fpljqj.cdr',
#  '154325 tvf.vhv',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd prcgb',
#  '$ ls',
#  '69766 lnsvgqq.psj',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd jfbhz',
#  '$ ls',
#  '286498 ssbmgts',
#  '$ cd ..',
#  '$ cd vpgpz',
#  '$ ls',
#  '63751 gsvjgj.jsm',
#  '220526 vvlvcs.dpc',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  'dir fpljqj',
#  '182996 ghtzhjwf.nls',
#  'dir jcffb',
#  'dir jzl',
#  'dir nzlv',
#  '6752 snwmlr.glp',
#  '$ cd fpljqj',
#  '$ ls',
#  'dir btsdth',
#  'dir fwdw',
#  'dir nqfdhlcg',
#  'dir qmrsvfvw',
#  '203470 svsvcgj',
#  '$ cd btsdth',
#  '$ ls',
#  '176953 szft.bjb',
#  '$ cd ..',
#  '$ cd fwdw',
#  '$ ls',
#  '95939 crffczjt.gsq',
#  'dir mbgzf',
#  'dir rqdnjfdq',
#  '296397 zfl.fjb',
#  '$ cd mbgzf',
#  '$ ls',
#  '179220 mjfjqw.ccv',
#  '$ cd ..',
#  '$ cd rqdnjfdq',
#  '$ ls',
#  '204152 qmrsvfvw',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  '194439 gwc.wdp',
#  '167934 qfwdmzfv.ggd',
#  '151571 sczw',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  'dir dwc',
#  '103919 gfzgg',
#  '6816 shpch.chl',
#  '$ cd dwc',
#  '$ ls',
#  '17813 gsvjgj.jsm',
#  '80522 hbhlv.pqh',
#  'dir htpt',
#  'dir hwg',
#  'dir nslrrrfg',
#  'dir psgw',
#  '231148 sdfvzdwm.wlz',
#  '102460 szft.bjb',
#  'dir wjlfgt',
#  '$ cd htpt',
#  '$ ls',
#  '162107 wjv',
#  '$ cd ..',
#  '$ cd hwg',
#  '$ ls',
#  'dir gslvrbt',
#  'dir qmrsvfvw',
#  '$ cd gslvrbt',
#  '$ ls',
#  'dir fjwn',
#  '107757 gsvjgj.jsm',
#  '$ cd fjwn',
#  '$ ls',
#  '268653 qptczjlq.prv',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '10557 nqfdhlcg',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd nslrrrfg',
#  '$ ls',
#  '112961 gsvjgj.jsm',
#  'dir hjgbgq',
#  'dir jctqdpq',
#  'dir qgfb',
#  'dir zfl',
#  '$ cd hjgbgq',
#  '$ ls',
#  '124947 mjfjqw.ccv',
#  '$ cd ..',
#  '$ cd jctqdpq',
#  '$ ls',
#  '203489 vgfhrl',
#  '$ cd ..',
#  '$ cd qgfb',
#  '$ ls',
#  '33980 nqfdhlcg.pqs',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  '193098 gsvjgj.jsm',
#  'dir vmzghf',
#  '26070 zfnppjsz',
#  '$ cd vmzghf',
#  '$ ls',
#  '235035 szft.bjb',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd psgw',
#  '$ ls',
#  '55808 gsvjgj.jsm',
#  '214300 wjv',
#  '$ cd ..',
#  '$ cd wjlfgt',
#  '$ ls',
#  '201399 qfwdmzfv.ggd',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd jcffb',
#  '$ ls',
#  '81815 szft.bjb',
#  '$ cd ..',
#  '$ cd jzl',
#  '$ ls',
#  '155651 gsvjgj.jsm',
#  'dir shrf',
#  '$ cd shrf',
#  '$ ls',
#  '57545 fpljqj.pcb',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd nzlv',
#  '$ ls',
#  '115992 bmmnj.ghw',
#  '100862 ghtzhjwf.nls',
#  'dir qwjpjw',
#  'dir rhbtbjp',
#  'dir rlmzs',
#  '60695 szft.bjb',
#  '3260 vzgwmrnc',
#  'dir wwnnj',
#  '17546 zdstndwj.lms',
#  '$ cd qwjpjw',
#  '$ ls',
#  'dir dpwp',
#  'dir fzdcjr',
#  '173669 gsvjgj.jsm',
#  'dir nmnbv',
#  'dir nqfdhlcg',
#  'dir plzdzdnm',
#  '135543 qfwdmzfv.ggd',
#  '246217 qmrsvfvw',
#  'dir sgpcqqm',
#  '141900 wvt.rfz',
#  '$ cd dpwp',
#  '$ ls',
#  '214058 wjv.zqs',
#  '94614 zrtbln',
#  '$ cd ..',
#  '$ cd fzdcjr',
#  '$ ls',
#  '236058 jcn.fzn',
#  '$ cd ..',
#  '$ cd nmnbv',
#  '$ ls',
#  '215145 lllgsbb',
#  '$ cd ..',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  '61644 ghtzhjwf.nls',
#  '238094 qfwdmzfv.ggd',
#  '183057 szft.bjb',
#  '17501 wjv.pln',
#  '$ cd ..',
#  '$ cd plzdzdnm',
#  '$ ls',
#  '243979 fpljqj.lnj',
#  '$ cd ..',
#  '$ cd sgpcqqm',
#  '$ ls',
#  '262759 hjffwcls',
#  '100893 mvs.cgz',
#  'dir nzhlcl',
#  '170443 szft.bjb',
#  'dir zfl',
#  '$ cd nzhlcl',
#  '$ ls',
#  'dir wcfl',
#  '$ cd wcfl',
#  '$ ls',
#  '24502 mjfjqw.ccv',
#  '145029 zfl.lpp',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  '176653 ghtzhjwf.nls',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd rhbtbjp',
#  '$ ls',
#  'dir nqfdhlcg',
#  '232788 pmj.cmm',
#  'dir zfvbc',
#  '$ cd nqfdhlcg',
#  '$ ls',
#  '72379 gqpcrtpw.nsm',
#  '$ cd ..',
#  '$ cd zfvbc',
#  '$ ls',
#  '19204 dqbs.ddg',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd rlmzs',
#  '$ ls',
#  '232862 fpljqj.rps',
#  '5558 lmgss.dtf',
#  '$ cd ..',
#  '$ cd wwnnj',
#  '$ ls',
#  '260417 cwjsrptm.hlm',
#  '216130 gsvjgj.jsm',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  'dir fpljqj',
#  'dir hllbt',
#  'dir nqfdhlcg',
#  '$ cd fpljqj',
#  '$ ls',
#  'dir qmrsvfvw',
#  'dir tdnp',
#  'dir vhtwd',
#  'dir wnlzd',
#  'dir ztttgd',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '218325 fpljqj.zhj',
#  '220402 qfwdmzfv.ggd',
#  '$ cd ..',
#  '$ cd tdnp',
#  '$ ls',
#  '46936 fmgz',
#  'dir gdsqdtw',
#  'dir tpcbjc',
#  'dir zfl',
#  '$ cd gdsqdtw',
#  '$ ls',
#  '128812 cnfpsb.qjr',
#  '185390 ghtzhjwf.nls',
#  '147220 qfwdmzfv.ggd',
#  '$ cd ..',
#  '$ cd tpcbjc',
#  '$ ls',
#  '188075 szft.bjb',
#  '243171 zdprcqs.qwf',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  'dir nnschfl',
#  'dir qmrsvfvw',
#  'dir szlbls',
#  '109443 wjv',
#  '$ cd nnschfl',
#  '$ ls',
#  '139948 szft.bjb',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  'dir bdn',
#  'dir fpljqj',
#  '168508 fpljqj.ljd',
#  'dir hwgbwqmm',
#  'dir nwhl',
#  '224059 qfwdmzfv.ggd',
#  '$ cd bdn',
#  '$ ls',
#  '179118 jdrdjf.ppn',
#  '74443 lpp',
#  '$ cd ..',
#  '$ cd fpljqj',
#  '$ ls',
#  '125033 mtfgm.pjf',
#  '$ cd ..',
#  '$ cd hwgbwqmm',
#  '$ ls',
#  '133673 vrvhgbz.ttb',
#  '$ cd ..',
#  '$ cd nwhl',
#  '$ ls',
#  '187017 fpljqj',
#  '149238 mjfjqw.ccv',
#  'dir mqzrmjr',
#  'dir vdjgqfc',
#  'dir zfzfbq',
#  '$ cd mqzrmjr',
#  '$ ls',
#  'dir fpljqj',
#  '131712 jmnsst.bmv',
#  '289722 ppdhjswn',
#  'dir qmrsvfvw',
#  '30641 zfl.trb',
#  '$ cd fpljqj',
#  '$ ls',
#  '286985 lwmfmsr.tln',
#  '253325 mjfjqw.ccv',
#  '194077 vgb.glm',
#  '38905 wjv.vgs',
#  '$ cd ..',
#  '$ cd qmrsvfvw',
#  '$ ls',
#  '87468 nngbnwds.qcn',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd vdjgqfc',
#  '$ ls',
#  '122025 rnvwf.mrp',
#  '261944 wdwgml',
#  '$ cd ..',
#  '$ cd zfzfbq',
#  '$ ls',
#  'dir bwmrf',
#  'dir zfl',
#  '$ cd bwmrf',
#  '$ ls',
#  '222502 gsvjgj.jsm',
#  '$ cd ..',
#  '$ cd zfl',
#  '$ ls',
#  '10297 ghtzhjwf.nls',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd szlbls',
#  '$ ls',
#  '10968 bqbclc.nfl',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd vhtwd',
#  '$ ls',
#  '188024 dgz',
#  '$ cd ..',
#  '$ cd wnlzd',
#  '$ ls',
#  '201028 gsvjgj.jsm',
#  'dir mcnnsv',
#  'dir mctpdbs',
#  '47879 szft.bjb',
#  'dir tjqfts',
#  '164406 zpdmdrw',
#  '$ cd mcnnsv',
#  '$ ls',
#  'dir lclgj',
#  'dir sjdbnbqw',
#  'dir tlj',
#  'dir wjv',
#  '$ cd lclgj',
#  '$ ls',
#  '192605 fgpjczr.grp',
#  '65758 hhrf.fgg',
#  '$ cd ..',
#  '$ cd sjdbnbqw',
#  '$ ls',
#  '89058 ghtzhjwf.nls',
#  '191742 rlmwjg.dpl',
#  '179479 zswc.snt',
#  '$ cd ..',
#  '$ cd tlj',
#  '$ ls',
#  '183447 fpljqj.fgf',
#  '$ cd ..',
#  '$ cd wjv',
#  '$ ls',
#  '1517 pbwr',
#  '189647 szft.bjb',
#  '$ cd ..',
#  '$ cd ..',
#  '$ cd mctpdbs',
#  '$ ls',
#  '120327 szft.bjb',
#  '$ cd ..',
#  '$ cd tjqfts',
#  '$ ls',
#  'dir crvw',
#  '$ cd crvw',
#  '$ ls',
#  '289523 lcshtlgf.lrv',
#  '169176 szft.bjb',
#  ...]

# %%
class File:
    def __init__(self, name, parent, filepath, size):
        self.name = name
        self.parent = parent
        self.filepath = filepath
        self.size = size

    def get_size(self):
        return self.size

class Directory:
    def __init__(self, name, parent, filepath, children = [], files = []):
        self.name = name
        self.parent = parent
        self.filepath = filepath
        self.children = children
        self.files = files

    def touch_file(self, file_dict):
        file = File(name=file_dict['name'],
                    parent=self,
                    filepath = self.filepath + file_dict['name'],
                    size=file_dict['size'])
        self.files.append(file)
        return

    def mkdir(self, child_name):
        child_dir = Directory(name=child_name, 
                              parent=self,
                              filepath = self.filepath + child_name + '/',
                              children = [], 
                              files = [])
        self.children.append(child_dir)
        return child_dir

    def cd_parent(self):
        return self.parent

    def cd_child(self, child_name):
        child_dir = None
        for dir in self.children:
            if dir.name==child_name:
                child_dir = dir

        if child_dir:
            return child_dir
        else:
            return self.mkdir(child_name)

    def cd_root(self):
        if self.parent == None:
            return self
        else:
            self = self.cd_parent()
            self.cd_root()

    def get_size_of_all_files(self):
        total_size = 0
        if len(self.files) > 0:
            for file in self.files:
                total_size += file.get_size()
        return total_size

    def get_subdir_size(self):
        total_size = 0
        if len(self.children) > 0:
            for child in self.children:
                total_size += child.get_size()
        return total_size

    def get_size(self):
        file_size = self.get_size_of_all_files()
        subdir_size = self.get_subdir_size()
        return file_size + subdir_size

    def get_filepaths(self, cur_list):
        files = self.files
        for file in files:
            file_list = [file.filepath, 'file', file.size]
            cur_list.append(file_list)
            print(file.filepath)
        
        if len(self.children) > 0:
            for child in self.children:
                child_list = [child.filepath, 'dir', child.get_size()]
                cur_list.append(child_list)
                print(child.filepath, child.get_size())

                if len(child.children) == 0:
                    continue
                else:
                    child.get_filepaths(cur_list)

        return cur_list

    def print_filesystem(self):
        root = self.cd_root()
        file_list = []
        output_list = root.get_filepaths(file_list)
        root_list = [root.filepath, 'dir', root.get_size()]
        output_list.append(root_list)
        return pd.DataFrame(output_list, columns=['filepath', 'type', 'size'])

# %%
def build_filesystem(lines, root):
    # # Build root directory
    # root = Directory(name='/', parent=None, filepath='/')
    current_dir = root

    for line in lines:
        # Go to root
        if line[0:6]=='$ cd /':
            current_dir = current_dir.cd_root()
            print("GOING TO ROOT: ", current_dir.filepath)
        
        # List files
        elif line=='$ ls':
            print("LS...")
            continue

        # Back up a level
        elif line[0:7]=='$ cd ..':
            current_dir = current_dir.cd_parent()
            print("GOING TO PARENT: ", current_dir.filepath)

        # Cd to nested dir
        elif line[0:4]=='$ cd':
            dir_name = line[5:]
            current_dir = current_dir.cd_child(dir_name)
            print("GOING TO DIR: ", dir_name, current_dir.filepath)

        # If no $ in front of line, add item to dict
        else:
            line_vals = line.split(' ')
            # If directory, store in file_system
            if line_vals[0] == 'dir':
                _ = current_dir.mkdir(child_name=line_vals[1])
                print("CREATING CHILD: ", line_vals[1], [x.filepath for x in current_dir.children])
                continue
            else:
                file_dict = {'name': line_vals[1], 'size': int(line_vals[0])}
                current_dir.touch_file(file_dict=file_dict)
                print("CREATING FILE, ", line_vals[1], [x.filepath for x in current_dir.files])

    root_dir = current_dir.cd_root()

    return root

# %%
# Build root directory
root = Directory(name='/', parent=None, filepath='/')

# %%
file_system = build_filesystem(master_list, root)
# Out:
# GOING TO ROOT:  /
# LS...
# CREATING CHILD:  fpljqj ['/fpljqj/']
# CREATING FILE,  ghtzhjwf.nls ['/ghtzhjwf.nls']
# CREATING CHILD:  gsdsbld ['/fpljqj/', '/gsdsbld/']
# CREATING CHILD:  hbmjtb ['/fpljqj/', '/gsdsbld/', '/hbmjtb/']
# CREATING FILE,  mjfjqw.ccv ['/ghtzhjwf.nls', '/mjfjqw.ccv']
# CREATING CHILD:  nfn ['/fpljqj/', '/gsdsbld/', '/hbmjtb/', '/nfn/']
# CREATING CHILD:  qmrsvfvw ['/fpljqj/', '/gsdsbld/', '/hbmjtb/', '/nfn/', '/qmrsvfvw/']
# CREATING FILE,  qqjnqb.chd ['/ghtzhjwf.nls', '/mjfjqw.ccv', '/qqjnqb.chd']
# CREATING CHILD:  svgbqd ['/fpljqj/', '/gsdsbld/', '/hbmjtb/', '/nfn/', '/qmrsvfvw/', '/svgbqd/']
# GOING TO DIR:  fpljqj /fpljqj/
# LS...
# CREATING FILE,  ghtzhjwf.nls ['/fpljqj/ghtzhjwf.nls']
# CREATING FILE,  gsvjgj.jsm ['/fpljqj/ghtzhjwf.nls', '/fpljqj/gsvjgj.jsm']
# CREATING FILE,  hghnrbqg.rzb ['/fpljqj/ghtzhjwf.nls', '/fpljqj/gsvjgj.jsm', '/fpljqj/hghnrbqg.rzb']
# GOING TO PARENT:  /
# GOING TO DIR:  gsdsbld /gsdsbld/
# LS...
# CREATING CHILD:  npmncvhh ['/gsdsbld/npmncvhh/']
# CREATING CHILD:  qmrsvfvw ['/gsdsbld/npmncvhh/', '/gsdsbld/qmrsvfvw/']
# CREATING CHILD:  sqtnlr ['/gsdsbld/npmncvhh/', '/gsdsbld/qmrsvfvw/', '/gsdsbld/sqtnlr/']
# CREATING CHILD:  vzndpc ['/gsdsbld/npmncvhh/', '/gsdsbld/qmrsvfvw/', '/gsdsbld/sqtnlr/', '/gsdsbld/vzndpc/']
# GOING TO DIR:  npmncvhh /gsdsbld/npmncvhh/
# LS...
# CREATING FILE,  dwbgr.ztr ['/gsdsbld/npmncvhh/dwbgr.ztr']
# CREATING FILE,  fzjmcq ['/gsdsbld/npmncvhh/dwbgr.ztr', '/gsdsbld/npmncvhh/fzjmcq']
# CREATING CHILD:  mphhrqf ['/gsdsbld/npmncvhh/mphhrqf/']
# CREATING CHILD:  rnmvggfd ['/gsdsbld/npmncvhh/mphhrqf/', '/gsdsbld/npmncvhh/rnmvggfd/']
# CREATING FILE,  zfl.ghv ['/gsdsbld/npmncvhh/dwbgr.ztr', '/gsdsbld/npmncvhh/fzjmcq', '/gsdsbld/npmncvhh/zfl.ghv']
# GOING TO DIR:  mphhrqf /gsdsbld/npmncvhh/mphhrqf/
# LS...
# CREATING CHILD:  qlcfs ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/']
# CREATING FILE,  shmcrf.wlr ['/gsdsbld/npmncvhh/mphhrqf/shmcrf.wlr']
# CREATING CHILD:  zwsnwvnv ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/', '/gsdsbld/npmncvhh/mphhrqf/zwsnwvnv/']
# GOING TO DIR:  qlcfs /gsdsbld/npmncvhh/mphhrqf/qlcfs/
# LS...
# CREATING FILE,  fpljqj.pdw ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/fpljqj.pdw']
# CREATING FILE,  hsclcqqt.pff ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/fpljqj.pdw', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/hsclcqqt.pff']
# CREATING CHILD:  htwl ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/']
# CREATING CHILD:  lqjhfdch ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/']
# CREATING FILE,  mdjzmbc.qtv ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/fpljqj.pdw', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/hsclcqqt.pff', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/mdjzmbc.qtv']
# CREATING CHILD:  nqfdhlcg ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/']
# CREATING FILE,  twgqhvft.cgw ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/fpljqj.pdw', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/hsclcqqt.pff', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/mdjzmbc.qtv', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/twgqhvft.cgw']
# CREATING FILE,  zclhcr ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/fpljqj.pdw', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/hsclcqqt.pff', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/mdjzmbc.qtv', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/twgqhvft.cgw', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zclhcr']
# CREATING CHILD:  zfl ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zfl/']
# CREATING CHILD:  zlqgr ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zfl/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/']
# GOING TO DIR:  htwl /gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/
# LS...
# CREATING FILE,  hmwnn.htq ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/hmwnn.htq']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/
# GOING TO DIR:  lqjhfdch /gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/
# LS...
# CREATING FILE,  tpdsgf.hgd ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/tpdsgf.hgd']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/
# GOING TO DIR:  nqfdhlcg /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/
# LS...
# CREATING CHILD:  dhjfqv ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/dhjfqv/']
# CREATING FILE,  ghtzhjwf.nls ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/ghtzhjwf.nls']
# CREATING FILE,  qfwdmzfv.ggd ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/ghtzhjwf.nls', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/qfwdmzfv.ggd']
# GOING TO DIR:  dhjfqv /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/dhjfqv/
# LS...
# CREATING FILE,  dqs.wht ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/dhjfqv/dqs.wht']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/
# GOING TO DIR:  zfl /gsdsbld/npmncvhh/mphhrqf/qlcfs/zfl/
# LS...
# CREATING FILE,  wlsd ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zfl/wlsd']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/
# GOING TO DIR:  zlqgr /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/
# LS...
# CREATING CHILD:  crs ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/crs/']
# CREATING CHILD:  whrm ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/crs/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/']
# CREATING CHILD:  zfl ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/crs/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/']
# GOING TO DIR:  crs /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/crs/
# LS...
# CREATING FILE,  szft.bjb ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/crs/szft.bjb']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/
# GOING TO DIR:  whrm /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/
# LS...
# CREATING FILE,  pcnl ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pcnl']
# CREATING CHILD:  pjzpqs ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/']
# GOING TO DIR:  pjzpqs /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/
# LS...
# CREATING CHILD:  smz ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/']
# CREATING FILE,  sqtst.lcz ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/sqtst.lcz']
# CREATING FILE,  trst ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/sqtst.lcz', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/trst']
# CREATING FILE,  vtgdsnmv ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/sqtst.lcz', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/trst', '/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/vtgdsnmv']
# GOING TO DIR:  smz /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/
# LS...
# CREATING FILE,  mjfjqw.ccv ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/mjfjqw.ccv']
# CREATING CHILD:  tdwqpg ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/tdwqpg/']
# GOING TO DIR:  tdwqpg /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/tdwqpg/
# LS...
# CREATING FILE,  wjv.rth ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/tdwqpg/wjv.rth']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/
# GOING TO DIR:  zfl /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/
# LS...
# CREATING CHILD:  hwlhshtr ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/hwlhshtr/']
# GOING TO DIR:  hwlhshtr /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/hwlhshtr/
# LS...
# CREATING FILE,  srrv.jst ['/gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/hwlhshtr/srrv.jst']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/qlcfs/
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/
# GOING TO DIR:  zwsnwvnv /gsdsbld/npmncvhh/mphhrqf/zwsnwvnv/
# LS...
# CREATING FILE,  ctmcqlz.nwh ['/gsdsbld/npmncvhh/mphhrqf/zwsnwvnv/ctmcqlz.nwh']
# CREATING FILE,  nqngjf ['/gsdsbld/npmncvhh/mphhrqf/zwsnwvnv/ctmcqlz.nwh', '/gsdsbld/npmncvhh/mphhrqf/zwsnwvnv/nqngjf']
# GOING TO PARENT:  /gsdsbld/npmncvhh/mphhrqf/
# GOING TO PARENT:  /gsdsbld/npmncvhh/
# GOING TO DIR:  rnmvggfd /gsdsbld/npmncvhh/rnmvggfd/
# LS...
# CREATING CHILD:  czzrdvc ['/gsdsbld/npmncvhh/rnmvggfd/czzrdvc/']
# CREATING FILE,  dnwtwzd ['/gsdsbld/npmncvhh/rnmvggfd/dnwtwzd']
# CREATING CHILD:  fcsjqg ['/gsdsbld/npmncvhh/rnmvggfd/czzrdvc/', '/gsdsbld/npmncvhh/rnmvggfd/fcsjqg/']
# CREATING CHILD:  fwdprwpq ['/gsdsbld/npmncvhh/rnmvggfd/czzrdvc/', '/gsdsbld/npmncvhh/rnmvggfd/fcsjqg/', '/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/']
# CREATING FILE,  qlnqwnzp.ttz ['/gsdsbld/npmncvhh/rnmvggfd/dnwtwzd', '/gsdsbld/npmncvhh/rnmvggfd/qlnqwnzp.ttz']
# CREATING CHILD:  tvglfb ['/gsdsbld/npmncvhh/rnmvggfd/czzrdvc/', '/gsdsbld/npmncvhh/rnmvggfd/fcsjqg/', '/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/', '/gsdsbld/npmncvhh/rnmvggfd/tvglfb/']
# GOING TO DIR:  czzrdvc /gsdsbld/npmncvhh/rnmvggfd/czzrdvc/
# LS...
# CREATING CHILD:  blplbjpw ['/gsdsbld/npmncvhh/rnmvggfd/czzrdvc/blplbjpw/']
# GOING TO DIR:  blplbjpw /gsdsbld/npmncvhh/rnmvggfd/czzrdvc/blplbjpw/
# LS...
# CREATING FILE,  zfl.zvw ['/gsdsbld/npmncvhh/rnmvggfd/czzrdvc/blplbjpw/zfl.zvw']
# GOING TO PARENT:  /gsdsbld/npmncvhh/rnmvggfd/czzrdvc/
# GOING TO PARENT:  /gsdsbld/npmncvhh/rnmvggfd/
# GOING TO DIR:  fcsjqg /gsdsbld/npmncvhh/rnmvggfd/fcsjqg/
# LS...
# CREATING FILE,  ghtzhjwf.nls ['/gsdsbld/npmncvhh/rnmvggfd/fcsjqg/ghtzhjwf.nls']
# GOING TO PARENT:  /gsdsbld/npmncvhh/rnmvggfd/
# GOING TO DIR:  fwdprwpq /gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/gsvjgj.jsm']
# CREATING FILE,  rgscvjq.zlw ['/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/gsvjgj.jsm', '/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/rgscvjq.zlw']
# CREATING FILE,  szft.bjb ['/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/gsvjgj.jsm', '/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/rgscvjq.zlw', '/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq/szft.bjb']
# CREATING CHILD:  zfl ['/gsdsbld/npmncvhh/rnmvggfd/fwdprwpq
# GOING TO DIR:  fpglbth /gsdsbld/qmrsvfvw/zcgfg/fpglbth/
# LS...
# CREATING FILE,  qlggch.tng ['/gsdsbld/qmrsvfvw/zcgfg/fpglbth/qlggch.tng']
# GOING TO PARENT:  /gsdsbld/qmrsvfvw/zcgfg/
# GOING TO DIR:  pfjz /gsdsbld/qmrsvfvw/zcgfg/pfjz/
# LS...
# CREATING FILE,  wplpj ['/gsdsbld/qmrsvfvw/zcgfg/pfjz/wplpj']
# GOING TO PARENT:  /gsdsbld/qmrsvfvw/zcgfg/
# GOING TO PARENT:  /gsdsbld/qmrsvfvw/
# GOING TO PARENT:  /gsdsbld/
# GOING TO DIR:  sqtnlr /gsdsbld/sqtnlr/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/gsdsbld/sqtnlr/gsvjgj.jsm']
# CREATING CHILD:  ngr ['/gsdsbld/sqtnlr/ngr/']
# CREATING FILE,  pmprhlg.rsg ['/gsdsbld/sqtnlr/gsvjgj.jsm', '/gsdsbld/sqtnlr/pmprhlg.rsg']
# CREATING FILE,  szft.bjb ['/gsdsbld/sqtnlr/gsvjgj.jsm', '/gsdsbld/sqtnlr/pmprhlg.rsg', '/gsdsbld/sqtnlr/szft.bjb']
# CREATING FILE,  tfqcnn.hlf ['/gsdsbld/sqtnlr/gsvjgj.jsm', '/gsdsbld/sqtnlr/pmprhlg.rsg', '/gsdsbld/sqtnlr/szft.bjb', '/gsdsbld/sqtnlr/tfqcnn.hlf']
# GOING TO DIR:  ngr /gsdsbld/sqtnlr/ngr/
# LS...
# CREATING CHILD:  fdhd ['/gsdsbld/sqtnlr/ngr/fdhd/']
# CREATING CHILD:  hwsqqt ['/gsdsbld/sqtnlr/ngr/fdhd/', '/gsdsbld/sqtnlr/ngr/hwsqqt/']
# CREATING CHILD:  qmrsvfvw ['/gsdsbld/sqtnlr/ngr/fdhd/', '/gsdsbld/sqtnlr/ngr/hwsqqt/', '/gsdsbld/sqtnlr/ngr/qmrsvfvw/']
# GOING TO DIR:  fdhd /gsdsbld/sqtnlr/ngr/fdhd/
# LS...
# CREATING FILE,  fhhp ['/gsdsbld/sqtnlr/ngr/fdhd/fhhp']
# CREATING CHILD:  fpljqj ['/gsdsbld/sqtnlr/ngr/fdhd/fpljqj/']
# CREATING FILE,  nqfdhlcg.gwf ['/gsdsbld/sqtnlr/ngr/fdhd/fhhp', '/gsdsbld/sqtnlr/ngr/fdhd/nqfdhlcg.gwf']
# CREATING FILE,  ptcrmc.wwr ['/gsdsbld/sqtnlr/ngr/fdhd/fhhp', '/gsdsbld/sqtnlr/ngr/fdhd/nqfdhlcg.gwf', '/gsdsbld/sqtnlr/ngr/fdhd/ptcrmc.wwr']
# GOING TO DIR:  fpljqj /gsdsbld/sqtnlr/ngr/fdhd/fpljqj/
# LS...
# CREATING FILE,  rtfhcbc.pqj ['/gsdsbld/sqtnlr/ngr/fdhd/fpljqj/rtfhcbc.pqj']
# GOING TO PARENT:  /gsdsbld/sqtnlr/ngr/fdhd/
# GOING TO PARENT:  /gsdsbld/sqtnlr/ngr/
# GOING TO DIR:  hwsqqt /gsdsbld/sqtnlr/ngr/hwsqqt/
# LS...
# CREATING FILE,  zvmgv.tcd ['/gsdsbld/sqtnlr/ngr/hwsqqt/zvmgv.tcd']
# GOING TO PARENT:  /gsdsbld/sqtnlr/ngr/
# GOING TO DIR:  qmrsvfvw /gsdsbld/sqtnlr/ngr/qmrsvfvw/
# LS...
# CREATING FILE,  qfwdmzfv.ggd ['/gsdsbld/sqtnlr/ngr/qmrsvfvw/qfwdmzfv.ggd']
# GOING TO PARENT:  /gsdsbld/sqtnlr/ngr/
# GOING TO PARENT:  /gsdsbld/sqtnlr/
# GOING TO PARENT:  /gsdsbld/
# GOING TO DIR:  vzndpc /gsdsbld/vzndpc/
# LS...
# CREATING FILE,  fpljqj.nbh ['/gsdsbld/vzndpc/fpljqj.nbh']
# GOING TO PARENT:  /gsdsbld/
# GOING TO PARENT:  /
# GOING TO DIR:  hbmjtb /hbmjtb/
# LS...
# CREATING FILE,  hlvjdg ['/hbmjtb/hlvjdg']
# CREATING CHILD:  lndmtm ['/hbmjtb/lndmtm/']
# CREATING FILE,  rtpvh.srl ['/hbmjtb/hlvjdg', '/hbmjtb/rtpvh.srl']
# CREATING CHILD:  sgt ['/hbmjtb/lndmtm/', '/hbmjtb/sgt/']
# CREATING CHILD:  tgjszvsg ['/hbmjtb/lndmtm/', '/hbmjtb/sgt/', '/hbmjtb/tgjszvsg/']
# CREATING FILE,  zrshs.phz ['/hbmjtb/hlvjdg', '/hbmjtb/rtpvh.srl', '/hbmjtb/zrshs.phz']
# CREATING CHILD:  ztrvv ['/hbmjtb/lndmtm/', '/hbmjtb/sgt/', '/hbmjtb/tgjszvsg/', '/hbmjtb/ztrvv/']
# GOING TO DIR:  lndmtm /hbmjtb/lndmtm/
# LS...
# CREATING CHILD:  fpljqj ['/hbmjtb/lndmtm/fpljqj/']
# CREATING CHILD:  hscwh ['/hbmjtb/lndmtm/fpljqj/', '/hbmjtb/lndmtm/hscwh/']
# CREATING CHILD:  wjv ['/hbmjtb/lndmtm/fpljqj/', '/hbmjtb/lndmtm/hscwh/', '/hbmjtb/lndmtm/wjv/']
# GOING TO DIR:  fpljqj /hbmjtb/lndmtm/fpljqj/
# LS...
# CREATING FILE,  qmrsvfvw ['/hbmjtb/lndmtm/fpljqj/qmrsvfvw']
# GOING TO PARENT:  /hbmjtb/lndmtm/
# GOING TO DIR:  hscwh /hbmjtb/lndmtm/hscwh/
# LS...
# CREATING CHILD:  qgz ['/hbmjtb/lndmtm/hscwh/qgz/']
# CREATING CHILD:  qmrsvfvw ['/hbmjtb/lndmtm/hscwh/qgz/', '/hbmjtb/lndmtm/hscwh/qmrsvfvw/']
# GOING TO DIR:  qgz /hbmjtb/lndmtm/hscwh/qgz/
# LS...
# CREATING FILE,  szft.bjb ['/hbmjtb/lndmtm/hscwh/qgz/szft.bjb']
nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/gsvjgj.jsm']
# CREATING CHILD:  lcdfdmlj ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/lcdfdmlj/']
# CREATING CHILD:  pthwnf ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/lcdfdmlj/', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/pthwnf/']
# CREATING FILE,  qfwdmzfv.ggd ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/gsvjgj.jsm', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/qfwdmzfv.ggd']
# CREATING FILE,  qmwr.csp ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/gsvjgj.jsm', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/qfwdmzfv.ggd', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/qmwr.csp']
# CREATING FILE,  scwd.mdc ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/gsvjgj.jsm', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/qfwdmzfv.ggd', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/qmwr.csp', '/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/scwd.mdc']
# GOING TO DIR:  lcdfdmlj /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/lcdfdmlj/
# LS...
# CREATING FILE,  mjfjqw.ccv ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/lcdfdmlj/mjfjqw.ccv']
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/
# GOING TO DIR:  pthwnf /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/pthwnf/
# LS...
# CREATING FILE,  fgcwjjz ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/pthwnf/fgcwjjz']
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/tfdcg/
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/
# GOING TO DIR:  vwlbtgnh /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/
# LS...
# CREATING CHILD:  nqfdhlcg ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/nqfdhlcg/']
# GOING TO DIR:  nqfdhlcg /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/nqfdhlcg/
# LS...
# CREATING CHILD:  lnwtl ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/nqfdhlcg/lnwtl/']
# GOING TO DIR:  lnwtl /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/nqfdhlcg/lnwtl/
# LS...
# CREATING FILE,  cgj.pdg ['/nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/nqfdhlcg/lnwtl/cgj.pdg']
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/nqfdhlcg/
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/vwlbtgnh/
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/pmcpnqrr/
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/
# GOING TO DIR:  wvvzbt /nfn/mpz/gntjg/hvcdpzr/wvvzbt/
# LS...
# CREATING FILE,  bvhd ['/nfn/mpz/gntjg/hvcdpzr/wvvzbt/bvhd']
# CREATING FILE,  qzwgj.bmb ['/nfn/mpz/gntjg/hvcdpzr/wvvzbt/bvhd', '/nfn/mpz/gntjg/hvcdpzr/wvvzbt/qzwgj.bmb']
# GOING TO PARENT:  /nfn/mpz/gntjg/hvcdpzr/
# GOING TO PARENT:  /nfn/mpz/gntjg/
# GOING TO DIR:  lth /nfn/mpz/gntjg/lth/
# LS...
# CREATING CHILD:  dmbf ['/nfn/mpz/gntjg/lth/dmbf/']
# CREATING FILE,  ghtzhjwf.nls ['/nfn/mpz/gntjg/lth/ghtzhjwf.nls']
# CREATING CHILD:  ndbcrvw ['/nfn/mpz/gntjg/lth/dmbf/', '/nfn/mpz/gntjg/lth/ndbcrvw/']
# CREATING CHILD:  shsgqzn ['/nfn/mpz/gntjg/lth/dmbf/', '/nfn/mpz/gntjg/lth/ndbcrvw/', '/nfn/mpz/gntjg/lth/shsgqzn/']
# CREATING FILE,  zfl.tdf ['/nfn/mpz/gntjg/lth/ghtzhjwf.nls', '/nfn/mpz/gntjg/lth/zfl.tdf']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/
# GOING TO DIR:  qmrsvfvw /nfn/mpz/zfl/fpljqj/qmrsvfvw/
# LS...
# CREATING CHILD:  dwc ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/']
# CREATING FILE,  gfzgg ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/gfzgg']
# CREATING FILE,  shpch.chl ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/gfzgg', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/shpch.chl']
# GOING TO DIR:  dwc /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/gsvjgj.jsm']
# CREATING FILE,  hbhlv.pqh ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/gsvjgj.jsm', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hbhlv.pqh']
# CREATING CHILD:  htpt ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/']
# CREATING CHILD:  hwg ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/']
# CREATING CHILD:  nslrrrfg ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/']
# CREATING CHILD:  psgw ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/psgw/']
# CREATING FILE,  sdfvzdwm.wlz ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/gsvjgj.jsm', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hbhlv.pqh', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/sdfvzdwm.wlz']
# CREATING FILE,  szft.bjb ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/gsvjgj.jsm', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hbhlv.pqh', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/sdfvzdwm.wlz', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/szft.bjb']
# CREATING CHILD:  wjlfgt ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/psgw/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/wjlfgt/']
# GOING TO DIR:  htpt /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/
# LS...
# CREATING FILE,  wjv ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/htpt/wjv']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/
# GOING TO DIR:  hwg /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/
# LS...
# CREATING CHILD:  gslvrbt ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/']
# CREATING CHILD:  qmrsvfvw ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/qmrsvfvw/']
# GOING TO DIR:  gslvrbt /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/
# LS...
# CREATING CHILD:  fjwn ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/fjwn/']
# CREATING FILE,  gsvjgj.jsm ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/gsvjgj.jsm']
# GOING TO DIR:  fjwn /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/fjwn/
# LS...
# CREATING FILE,  qptczjlq.prv ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/fjwn/qptczjlq.prv']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/gslvrbt/
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/
# GOING TO DIR:  qmrsvfvw /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/qmrsvfvw/
# LS...
# CREATING FILE,  nqfdhlcg ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/qmrsvfvw/nqfdhlcg']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/hwg/
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/
# GOING TO DIR:  nslrrrfg /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/gsvjgj.jsm']
# CREATING CHILD:  hjgbgq ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/hjgbgq/']
# CREATING CHILD:  jctqdpq ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/hjgbgq/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/jctqdpq/']
# CREATING CHILD:  qgfb ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/hjgbgq/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/jctqdpq/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/qgfb/']
# CREATING CHILD:  zfl ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/hjgbgq/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/jctqdpq/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/qgfb/', '/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/zfl/']
# GOING TO DIR:  hjgbgq /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/hjgbgq/
# LS...
# CREATING FILE,  mjfjqw.ccv ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/hjgbgq/mjfjqw.ccv']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/
# GOING TO DIR:  jctqdpq /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/jctqdpq/
# LS...
# CREATING FILE,  vgfhrl ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/jctqdpq/vgfhrl']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/
# GOING TO DIR:  qgfb /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/qgfb/
# LS...
# CREATING FILE,  nqfdhlcg.pqs ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/qgfb/nqfdhlcg.pqs']
# GOING TO PARENT:  /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/
# GOING TO DIR:  zfl /nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/zfl/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg/zfl/gsvjgj.jsm']
# CREATING CHILD:  vmzghf ['/nfn/mpz/zfl/fpljqj/qmrsvfvw/dwc/nslrrrfg
# GOING TO DIR:  dpwp /nfn/mpz/zfl/nzlv/qwjpjw/dpwp/
# LS...
# CREATING FILE,  wjv.zqs ['/nfn/mpz/zfl/nzlv/qwjpjw/dpwp/wjv.zqs']
# CREATING FILE,  zrtbln ['/nfn/mpz/zfl/nzlv/qwjpjw/dpwp/wjv.zqs', '/nfn/mpz/zfl/nzlv/qwjpjw/dpwp/zrtbln']
# GOING TO PARENT:  /nfn/mpz/zfl/nzlv/qwjpjw/
# GOING TO DIR:  fzdcjr /nfn/mpz/zfl/nzlv/qwjpjw/fzdcjr/
# LS...
# CREATING FILE,  jcn.fzn ['/nfn/mpz/zfl/nzlv/qwjpjw/fzdcjr/jcn.fzn']
# GOING TO PARENT:  /nfn/mpz/zfl/nzlv/qwjpjw/
# GOING TO DIR:  nmnbv /nfn/mpz/zfl/nzlv/qwjpjw/nmnbv/
# LS...
# CREATING FILE,  lllgsbb ['/nfn/mpz/zfl/nzlv/qwjpjw/nmnbv/lllgsbb']
# GOING TO PARENT:  /nfn/mpz/zfl/nzlv/qwjpjw/
# GOING TO DIR:  nqfdhlcg /nfn/mpz/zfl/nzlv/qwjpjw/nqfdhlcg/
# LS...
# CREATING FILE,  ghtzhjwf.nls ['/nfn/mpz/zfl/nzlv/qwjpjw/nqfdhlcg/ghtzhjwf.nls']
# ...
# CREATING CHILD:  nwhl ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/bdn/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/fpljqj/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/hwgbwqmm/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/']
# CREATING FILE,  qfwdmzfv.ggd ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/fpljqj.ljd', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/qfwdmzfv.ggd']
# GOING TO DIR:  bdn /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/bdn/
# LS...
# CREATING FILE,  jdrdjf.ppn ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/bdn/jdrdjf.ppn']
# CREATING FILE,  lpp ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/bdn/jdrdjf.ppn', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/bdn/lpp']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/
# GOING TO DIR:  fpljqj /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/fpljqj/
# LS...
# CREATING FILE,  mtfgm.pjf ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/fpljqj/mtfgm.pjf']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/
# GOING TO DIR:  hwgbwqmm /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/hwgbwqmm/
# LS...
# CREATING FILE,  vrvhgbz.ttb ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/hwgbwqmm/vrvhgbz.ttb']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/
# GOING TO DIR:  nwhl /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/
# LS...
# CREATING FILE,  fpljqj ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/fpljqj']
# CREATING FILE,  mjfjqw.ccv ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/fpljqj', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mjfjqw.ccv']
# CREATING CHILD:  mqzrmjr ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/']
# CREATING CHILD:  vdjgqfc ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/vdjgqfc/']
# CREATING CHILD:  zfzfbq ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/vdjgqfc/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/']
# GOING TO DIR:  mqzrmjr /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/
# LS...
# CREATING CHILD:  fpljqj ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/']
# CREATING FILE,  jmnsst.bmv ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/jmnsst.bmv']
# CREATING FILE,  ppdhjswn ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/jmnsst.bmv', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/ppdhjswn']
# CREATING CHILD:  qmrsvfvw ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/qmrsvfvw/']
# CREATING FILE,  zfl.trb ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/jmnsst.bmv', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/ppdhjswn', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/zfl.trb']
# GOING TO DIR:  fpljqj /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/
# LS...
# CREATING FILE,  lwmfmsr.tln ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/lwmfmsr.tln']
# CREATING FILE,  mjfjqw.ccv ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/lwmfmsr.tln', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/mjfjqw.ccv']
# CREATING FILE,  vgb.glm ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/lwmfmsr.tln', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/mjfjqw.ccv', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/vgb.glm']
# CREATING FILE,  wjv.vgs ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/lwmfmsr.tln', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/mjfjqw.ccv', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/vgb.glm', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/fpljqj/wjv.vgs']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/
# GOING TO DIR:  qmrsvfvw /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/qmrsvfvw/
# LS...
# CREATING FILE,  nngbnwds.qcn ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/qmrsvfvw/nngbnwds.qcn']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/mqzrmjr/
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/
# GOING TO DIR:  vdjgqfc /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/vdjgqfc/
# LS...
# CREATING FILE,  rnvwf.mrp ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/vdjgqfc/rnvwf.mrp']
# CREATING FILE,  wdwgml ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/vdjgqfc/rnvwf.mrp', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/vdjgqfc/wdwgml']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/
# GOING TO DIR:  zfzfbq /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/
# LS...
# CREATING CHILD:  bwmrf ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/bwmrf/']
# CREATING CHILD:  zfl ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/bwmrf/', '/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/zfl/']
# GOING TO DIR:  bwmrf /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/bwmrf/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/bwmrf/gsvjgj.jsm']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/
# GOING TO DIR:  zfl /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/zfl/
# LS...
# CREATING FILE,  ghtzhjwf.nls ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/zfl/ghtzhjwf.nls']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/zfzfbq/
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/nwhl/
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/qmrsvfvw/
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/
# GOING TO DIR:  szlbls /nfn/qmrsvfvw/fpljqj/tdnp/zfl/szlbls/
# LS...
# CREATING FILE,  bqbclc.nfl ['/nfn/qmrsvfvw/fpljqj/tdnp/zfl/szlbls/bqbclc.nfl']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/zfl/
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/tdnp/
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/
# GOING TO DIR:  vhtwd /nfn/qmrsvfvw/fpljqj/vhtwd/
# LS...
# CREATING FILE,  dgz ['/nfn/qmrsvfvw/fpljqj/vhtwd/dgz']
# GOING TO PARENT:  /nfn/qmrsvfvw/fpljqj/
# GOING TO DIR:  wnlzd /nfn/qmrsvfvw/fpljqj/wnlzd/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/nfn/qmrsvfvw/fpljqj/wnlzd/gsvjgj.jsm']
# CREATING CHILD:  mcnnsv ['/nfn/qmrsvfvw/fpljqj/wnlzd/mcnnsv/']
# CREATING CHILD:  mctpdbs ['/nfn/qmrsvfvw/fpljqj/wnlzd/mcnnsv/', '/nfn/qmrsvfvw/fpljqj/wnlzd/mctpdbs/']
# CREATING FILE,  szft.bjb ['/nfn/qmrsvfvw/fpljqj/wnlzd/gsvjgj.jsm', '/nfn/qmrsvfvw/fpljqj/wnlzd/szft.bjb']
# CREATING CHILD:  tjqfts ['/nfn/qmrsvfvw/fpljqj/wnlzd/mcnnsv/', '/nfn/qmrsvfvw/fpljqj/wnlzd/mctpdbs/', '/nfn/qmrsvfvw/fpljqj/wnlzd/tjqfts/']
# CREATING FILE,  zpdmdrw ['/nfn/qmrsvfvw/fpljqj/wnlzd/gsvjgj.jsm', '/nfn/qmrsvfvw/fpljqj/wnlzd/szft.bjb', '/nfn/qmrsvfvw/fpljqj/wnlzd/zpdmdrw']
# GOING TO DIR:  mcnnsv /nfn/qmrsvfvw/fpljqj/wnlzd/mcnnsv/
# LS...
# CREATING CHILD:  lclgj ['/nfn/qmrsvfvw/fpljqj/wnlzd/mcnnsv
# CREATING FILE,  tdwzsgqh.zsh ['/nfn/qmrsvfvw/nqfdhlcg/tdwzsgqh.zsh']
# GOING TO DIR:  htnw /nfn/qmrsvfvw/nqfdhlcg/htnw/
# LS...
# CREATING FILE,  ggfpmb.pmz ['/nfn/qmrsvfvw/nqfdhlcg/htnw/ggfpmb.pmz']
# GOING TO PARENT:  /nfn/qmrsvfvw/nqfdhlcg/
# GOING TO PARENT:  /nfn/qmrsvfvw/
# GOING TO PARENT:  /nfn/
# GOING TO DIR:  zfl /nfn/zfl/
# LS...
# CREATING FILE,  mlbcw ['/nfn/zfl/mlbcw']
# CREATING CHILD:  rgvgqqd ['/nfn/zfl/rgvgqqd/']
# CREATING FILE,  rpv.qhp ['/nfn/zfl/mlbcw', '/nfn/zfl/rpv.qhp']
# CREATING FILE,  zfl.mvw ['/nfn/zfl/mlbcw', '/nfn/zfl/rpv.qhp', '/nfn/zfl/zfl.mvw']
# GOING TO DIR:  rgvgqqd /nfn/zfl/rgvgqqd/
# LS...
# CREATING FILE,  qnhpfr ['/nfn/zfl/rgvgqqd/qnhpfr']
# GOING TO PARENT:  /nfn/zfl/
# GOING TO PARENT:  /nfn/
# GOING TO PARENT:  /
# GOING TO DIR:  qmrsvfvw /qmrsvfvw/
# LS...
# CREATING FILE,  gsvjgj.jsm ['/qmrsvfvw/gsvjgj.jsm']
# GOING TO PARENT:  /
# GOING TO DIR:  svgbqd /svgbqd/
# LS...
# CREATING FILE,  bjc.vdh ['/svgbqd/bjc.vdh']

# %%
file_df = file_system.print_filesystem()
# Out:
# /ghtzhjwf.nls
# /mjfjqw.ccv
# /qqjnqb.chd
# /fpljqj/ 550949
# /gsdsbld/ 8021608
# /gsdsbld/npmncvhh/ 4964676
# /gsdsbld/npmncvhh/dwbgr.ztr
# /gsdsbld/npmncvhh/fzjmcq
# /gsdsbld/npmncvhh/zfl.ghv
# /gsdsbld/npmncvhh/mphhrqf/ 3207818
# /gsdsbld/npmncvhh/mphhrqf/shmcrf.wlr
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/ 2732978
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/fpljqj.pdw
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/hsclcqqt.pff
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/mdjzmbc.qtv
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/twgqhvft.cgw
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zclhcr
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/htwl/ 268134
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/ 21479
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/ 378276
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/ghtzhjwf.nls
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/qfwdmzfv.ggd
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/nqfdhlcg/dhjfqv/ 135074
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zfl/ 17334
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/ 1367324
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/crs/ 220281
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/ 1056575
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pcnl
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/ 776779
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/sqtst.lcz
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/trst
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/vtgdsnmv
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/ 407600
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/mjfjqw.ccv
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/whrm/pjzpqs/smz/tdwqpg/ 157907
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/ 90468
# /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/hwlhshtr/ 90468
# /gsdsbld/npmncvhh/mphhrqf/zwsnwvnv/ 363633
# /gsdsbld/npmncvhh/rnmvggfd/ 1254461
# /gsdsbld/npmncvhh/rnmvggfd/dnwtwzd
# /gsdsbld/npmncvhh/rnmvggfd/qlnqwnzp.ttz
# /gsdsbld/npmncvhh/rnmvggfd/czzrdvc/ 2835
# /gsdsbld/npmncvhh/rnmvggfd/czzrdvc/blplbjpw/ 2835
# /gsdsbld/npmncvhh/rnmvggfd/fcsjqg/ 81548
# /gsdsbld/npmncvhh/rnmvggfd/fwdprwpq
# /nfn/zfl/mlbcw
# /nfn/zfl/rpv.qhp
# /nfn/zfl/zfl.mvw
# /nfn/zfl/rgvgqqd/ 26778
# /qmrsvfvw/ 290013
# /svgbqd/ 69927

# %%
file_df
# Out:
#               filepath  type      size
# 0        /ghtzhjwf.nls  file    171526
# 1          /mjfjqw.ccv  file    296801
# 2          /qqjnqb.chd  file    102565
# 3             /fpljqj/   dir    550949
# 4            /gsdsbld/   dir   8021608
# ..                 ...   ...       ...
# 325   /nfn/zfl/zfl.mvw  file     64500
# 326  /nfn/zfl/rgvgqqd/   dir     26778
# 327         /qmrsvfvw/   dir    290013
# 328           /svgbqd/   dir     69927
# 329                  /   dir  44359867
#
# [330 rows x 3 columns]

# %%
dir_df = file_df[file_df['type']=='dir']
dir_df
# Out:
#                              filepath type      size
# 3                            /fpljqj/  dir    550949
# 4                           /gsdsbld/  dir   8021608
# 5                  /gsdsbld/npmncvhh/  dir   4964676
# 9          /gsdsbld/npmncvhh/mphhrqf/  dir   3207818
# 11   /gsdsbld/npmncvhh/mphhrqf/qlcfs/  dir   2732978
# ..                                ...  ...       ...
# 322                         /nfn/zfl/  dir    368100
# 326                 /nfn/zfl/rgvgqqd/  dir     26778
# 327                        /qmrsvfvw/  dir    290013
# 328                          /svgbqd/  dir     69927
# 329                                 /  dir  44359867
#
# [203 rows x 3 columns]

# %%
small_dir_df = dir_df[dir_df['size']<=100000]
print(small_dir_df.head())
small_total_size = small_dir_df['size'].sum()
print(small_total_size)
# Out:
#                                              filepath type   size
# 18          /gsdsbld/npmncvhh/mphhrqf/qlcfs/lqjhfdch/  dir  21479
# 23               /gsdsbld/npmncvhh/mphhrqf/qlcfs/zfl/  dir  17334
# 35         /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/  dir  90468
# 36  /gsdsbld/npmncvhh/mphhrqf/qlcfs/zlqgr/zfl/hwlh...  dir  90468
# 41                /gsdsbld/npmncvhh/rnmvggfd/czzrdvc/  dir   2835
# 1783610

# %% [markdown]
# ## Question 2

# %%
used_bytes = [x for x in file_df[file_df['filepath']=='/']['size']][0]

total_bytes = 70000000
total_needed = 30000000
max_used = total_bytes - total_needed
need_to_delete = used_bytes - max_used
print(used_bytes, max_used, need_to_delete)
# Out:
# 44359867 40000000 4359867

# %%
eligible_df = dir_df[dir_df['size']>=need_to_delete]
eligible_df
# Out:
#                        filepath type      size
# 4                     /gsdsbld/  dir   8021608
# 5            /gsdsbld/npmncvhh/  dir   4964676
# 76                     /hbmjtb/  dir   8465165
# 134                       /nfn/  dir  26391313
# 136                   /nfn/mpz/  dir  14470980
# 138             /nfn/mpz/gntjg/  dir   4825246
# 185               /nfn/mpz/zfl/  dir   9067124
# 226          /nfn/mpz/zfl/nzlv/  dir   4419451
# 255              /nfn/qmrsvfvw/  dir  11212301
# 256       /nfn/qmrsvfvw/fpljqj/  dir   7330912
# 258  /nfn/qmrsvfvw/fpljqj/tdnp/  dir   4370655
# 329                           /  dir  44359867

# %%
min_dir = eligible_df['size'].min()
min_dir
# Out:
# 4370655
